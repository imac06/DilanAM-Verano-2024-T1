# %%
import matplotlib.pyplot as plt
import numpy as np
from CodeBase.codigo import plot_histogram2
from CodeBase.codigo import plot_ojiva2
print("listo")
# Out:
# listo

# %%
datos = [250, 790, 470, 510, 500, 330, 300, 750, 580, 740, 420, 260, 440, 770, 400, 540, 530, 330, 390, 380, 340, 460, 530, 260, 410, 360, 270, 510, 630, 330]

# %%
plot_histogram2(datos, 6)

# %% [markdown]
# - La distribución de los datos esta sesgada hacia la izquierda
# - Hay pocos datos por encima de 700, lo que indica que esos valores son menos frecuentes en la muestra.

# %%
plot_ojiva2(datos, 6)
